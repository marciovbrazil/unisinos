# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
file1 = 'C:/Users/5235988/Downloads/Unisinos/Estatistica/Trabalho/atlas2013_dadosbrutos_pt_somente municipio.xlsx'

# %%
df1 = pd.read_excel(file1)

# %%
print(df1.head())
# Out:
#     ANO  UF  Codmun6  Codmun7              Município  ESPVIDA  FECTOT  MORT1  \
# 0  1991  11   110001  1100015  ALTA FLORESTA D'OESTE    62.01    4.08  45.58
# 1  1991  11   110002  1100023              ARIQUEMES    66.02    3.72  32.39
# 2  1991  11   110003  1100031                 CABIXI    63.16    3.89  41.52
# 3  1991  11   110004  1100049                 CACOAL    65.03    3.81  35.37
# 4  1991  11   110005  1100056             CEREJEIRAS    62.73    3.55  43.00
#
#    MORT5  RAZDEP  ...  PIA1517  PIA18M    POP   POPT  I_ESCOLARIDADE  \
# 0  58.05   73.50  ...      NaN     NaN  23417  22835           0.117
# 1  41.41   69.97  ...      NaN     NaN  56061  55018           0.200
# 2  52.94   77.23  ...      NaN     NaN   7601   5846           0.111
# 3  45.19   71.11  ...      NaN     NaN  69173  66534           0.176
# 4  54.82   71.09  ...      NaN     NaN  19451  19030           0.152
#
#    I_FREQ_PROP   IDHM  IDHM_E  IDHM_L  IDHM_R
# ...

# %%
df1.shape
# Out:
# (16695, 237)

# %%
df1.describe()
# Out:
#                 ANO            UF        Codmun6       Codmun7       ESPVIDA  \
# count  16695.000000  16695.000000   16695.000000  1.669500e+04  16695.000000
# mean    2000.333333     32.372327  325304.894160  3.253053e+06     68.411614
# std        7.760530      9.829369   98446.250439  9.844625e+05      5.445469
# min     1991.000000     11.000000  110001.000000  1.100015e+06     50.970000
# 25%     1991.000000     25.000000  251210.000000  2.512101e+06     64.830000
# 50%     2000.000000     31.000000  314620.000000  3.146206e+06     69.190000
# 75%     2010.000000     41.000000  411900.000000  4.119004e+06     72.650000
# max     2010.000000     53.000000  530010.000000  5.300108e+06     78.640000
#
#              FECTOT         MORT1         MORT5        RAZDEP       SOBRE40  \
# count  16695.000000  16695.000000  16695.000000  16695.000000  16695.000000
# mean       2.929683     33.267208     40.237872     62.984688     89.783321
# ...

# %%
df2 = df1[df1.UF == 42]

# %%
df2.head()
# Out:
#        ANO  UF  Codmun6  Codmun7      Município  ESPVIDA  FECTOT  MORT1  \
# 4310  1991  42   420005  4200051  ABDON BATISTA    67.97    2.61  30.84
# 4311  1991  42   420010  4200101   ABELARDO LUZ    70.05    2.42  24.70
# 4312  1991  42   420020  4200200     AGROLÂNDIA    68.46    3.18  29.32
# 4313  1991  42   420030  4200309     AGRONÔMICA    70.65    2.32  23.07
# 4314  1991  42   420040  4200408      ÁGUA DOCE    68.01    2.73  30.69
#
#       MORT5  RAZDEP  ...  PIA1517  PIA18M    POP   POPT  I_ESCOLARIDADE  \
# 4310  35.49   63.89  ...      NaN     NaN   3227   3227           0.144
# 4311  28.54   69.74  ...      NaN     NaN  12302  12181           0.220
# 4312  33.78   62.70  ...      NaN     NaN   8489   8450           0.174
# 4313  26.58   57.00  ...      NaN     NaN   4302   4271           0.181
# 4314  35.41   63.93  ...      NaN     NaN   6947   6879           0.224
#
#       I_FREQ_PROP   IDHM  IDHM_E  IDHM_L  IDHM_R
# 4310        0.225  0.410   0.194   0.716   0.495
# ...

# %%
dnulo = df2.isnull().sum()

# %%
dnulo.describe()
# Out:
# count    237.000000
# mean      66.759494
# std      126.076303
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      586.000000
# dtype: float64

# %%
dnulo.to_excel('C:/Users/5235988/Downloads/Unisinos/Estatistica/Trabalho/Nulos.xlsx')

# %%
sns.relplot(x='IDHM', y='I_ESCOLARIDADE', data=df2)

# %%
sns.relplot(x='IDHM', y='T_AGUA', data=df2)

# %%
sns.relplot(x='IDHM', y='T_LUZ', data=df2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
train = df2.loc[:, ['I_ESCOLARIDADE','T_AGUA','T_LUZ']]

# %%
test = df2.loc[:, ['IDHM']]

# %%
X_train, X_test, y_train, y_test = train_test_split(train, test, test_size=0.3, random_state=2)

# %%
regr = LinearRegression()

# %%
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred = regr.predict(X_test)

# %%
pred
# Out:
# array([[0.77721481],
#        [0.55182869],
#        [0.6667202 ],
#        [0.43204668],
#        [0.59698922],
#        [0.38981101],
#        [0.66640656],
#        [0.55434497],
#        [0.74134345],
#        [0.65408129],
#        [0.58739272],
#        [0.36268998],
#        [0.60706416],
#        [0.63803028],
#        [0.60072517],
#        [0.47608648],
#        [0.36732722],
#        [0.71722315],
#        [0.38846573],
#        [0.46073407],
#        [0.58170168],
#        [0.61608627],
#        [0.48464667],
#        [0.54285747],
#        [0.69964874],
#        [0.54542929],
#        [0.80501285],
#        [0.61869488],
#        [0.71041023],
#        [0.60479671],
#        [0.50651118],
#        [0.52862346],
#        [0.53329776],
#        [0.6563779 ],
#        [0.50521901],
#        [0.68498003],
#        [0.74627069],
#        [0.71765852],
#        [0.57503107],
#        [0.87238202],
#        [0.58073241],
#        [0.75655684],
#        [0.49104857],
# ...

# %%
regr.score(X_test, y_test)
# Out:
# 0.8504924339263679
